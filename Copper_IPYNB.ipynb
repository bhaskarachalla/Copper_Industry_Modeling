# %% [markdown]
# # Industrial Copper Modeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import datetime as dt
import warnings
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import json
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import SGDRegressor


from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\srinivasa rao\appdata\local\programs\python\python312\lib\site-packages (3.1.3)
# Requirement already satisfied: et-xmlfile in c:\users\srinivasa rao\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel(r"C:/Users/Srinivasa Rao/OneDrive/Documents/GUVI_Projects/Copper_Industry_Modeling/Copper_Set.xlsx")
df.head()
# Out:
#                                      id   item_date quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref  product_ref  delivery date  \
# 0                               DEQ1 S460MC   1670798778     20210701.0
# 1  0000000000000000000000000000000000104991   1668701718     20210401.0
# 2                                  S0380700       628377     20210101.0
# 3                   DX51D+ZM310MAO 2.3X1317   1668701718     20210101.0
# 4                           2_S275JR+AR-CL1       640665     20210301.0
#
#    selling_price
# 0         854.00
# 1        1047.00
# 2         644.33
# 3         768.00
# 4         577.00

# %%
data=df.copy(True)
data.T
# Out:
#                                              0       \
# id             EC06F063-9DF0-440C-8764-0B0C05A4F6AE
# item_date                                20210401.0
# quantity tons                             54.151139
# customer                                 30156308.0
# country                                        28.0
# status                                          Won
# item type                                         W
# application                                    10.0
# thickness                                       2.0
# width                                        1500.0
# material_ref                            DEQ1 S460MC
# product_ref                              1670798778
# delivery date                            20210701.0
# selling_price                                 854.0
#
#                                                  1       \
# id                 4E5F4B3D-DDDF-499D-AFDE-A3227EC49425
# item_date                                    20210401.0
# quantity tons                                768.024839
# customer                                     30202938.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                           0.8
# width                                            1210.0
# material_ref   0000000000000000000000000000000000104991
# product_ref                                  1668701718
# delivery date                                20210401.0
# selling_price                                    1047.0
#
#                                              2       \
# id             E140FF1B-2407-4C02-A0DD-780A093B1158
# item_date                                20210401.0
# quantity tons                            386.127949
# customer                                 30153963.0
# country                                        30.0
# status                                          Won
# item type                                        WI
# application                                    28.0
# thickness                                      0.38
# width                                         952.0
# material_ref                               S0380700
# product_ref                                  628377
# delivery date                            20210101.0
# selling_price                                644.33
#
#                                              3       \
# id             F8D507A0-9C62-4EFE-831E-33E1DA53BB50
# item_date                                20210401.0
# quantity tons                            202.411065
# customer                                 30349574.0
# country                                        32.0
# status                                          Won
# item type                                         S
# application                                    59.0
# thickness                                       2.3
# width                                        1317.0
# material_ref                DX51D+ZM310MAO 2.3X1317
# product_ref                              1668701718
# delivery date                            20210101.0
# selling_price                                 768.0
#
#                                              4       \
# id             4E1C4E78-152B-430A-8094-ADD889C9D0AD
# item_date                                20210401.0
# quantity tons                            785.526262
# customer                                 30211560.0
# country                                        28.0
# status                                          Won
# item type                                         W
# application                                    10.0
# thickness                                       4.0
# width                                        2000.0
# material_ref                        2_S275JR+AR-CL1
# product_ref                                  640665
# delivery date                            20210301.0
# selling_price                                 577.0
#
#                                                  5       \
# id                 FE372230-29B1-4A29-BB73-CB9D3078C286
# item_date                                    20210401.0
# quantity tons                                225.790676
# customer                                     30202938.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                           1.5
# width                                            1265.0
# material_ref   0000000000000000000000000000000000102325
# product_ref                                  1668701718
# delivery date                                20210401.0
# selling_price                                     983.0
#
#                                              6       \
# id             E1B47219-42C8-411D-AE46-AD5256DC4757
# item_date                                20210401.0
# quantity tons                              3.522613
# customer                                 30209509.0
# country                                        30.0
# status                                        Draft
# item type                                         W
# application                                    41.0
# thickness                                      0.38
# width                                        1125.0
# material_ref                      NBW_L+_A_1125_0.4
# product_ref                                  611993
# delivery date                            20210701.0
# selling_price                                  18.0
#
#                                                  7       \
# id                 AA3F18A2-A7D6-43DE-8644-F0632AE2CB68
# item_date                                    20210401.0
# quantity tons                                113.387124
# customer                                     30342192.0
# country                                            32.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                          0.68
# width                                            1220.0
# material_ref   0000000000000000000000000000000001000944
# product_ref                                      611993
# delivery date                                20210101.0
# selling_price                                     931.0
#
#                                                  8       \
# id                 2851F48B-DA32-4DF3-884B-17A3100DD65A
# item_date                                    20210401.0
# quantity tons                                 69.071853
# customer                                     30341428.0
# country                                            38.0
# status                                              Won
# item type                                             S
# application                                        10.0
# thickness                                           0.6
# width                                            1275.0
# material_ref   0000000000000000000000000000000000106786
# product_ref                                  1668701376
# delivery date                                20210701.0
# selling_price                                    1363.0
#
#                                                  9       ...  \
# id                 6E4D638C-A820-4A40-836F-C9D48BC65528  ...
# item_date                                    20210401.0  ...
# quantity tons                                630.626917  ...
# customer                                     30202938.0  ...
# country                                            25.0  ...
# status                                              Won  ...
# item type                                             W  ...
# application                                        41.0  ...
# thickness                                           1.5  ...
# width                                            1165.0  ...
# material_ref   0000000000000000000000000000000000102325  ...
# product_ref                                  1668701718  ...
# delivery date                                20210401.0  ...
# selling_price                                     983.0  ...
#
#                                                  181663  \
# id                 08F8F1D6-0DAC-42B5-BA8A-B6C99EF1700B
# item_date                                    20200702.0
# quantity tons                               1203.157826
# customer                                     30200854.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                          0.72
# width                                            1240.0
# material_ref   0000000000000000000000000000000001000856
# product_ref                                   164141591
# delivery date                                20200701.0
# selling_price                                     622.0
#
#                                                  181664  \
# id                 A33557CD-93EF-4828-8235-E0A576C1A925
# item_date                                    20200702.0
# quantity tons                                 603.11494
# customer                                     30200854.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                          0.85
# width                                            1240.0
# material_ref   0000000000000000000000000000000001000221
# product_ref                                   164141591
# delivery date                                20200701.0
# selling_price                                     609.0
#
#                                                  181665  \
# id                 F9B79E56-2EBF-417B-9802-7F575D1079F7
# item_date                                    20200702.0
# quantity tons                                  6.169226
# customer                                     30200854.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                          0.71
# width                                            1300.0
# material_ref   0000000000000000000000000000000001000224
# product_ref                                   164141591
# delivery date                                20200701.0
# selling_price                                     608.0
#
#                                                  181666  \
# id                 C01DE4E8-BC5F-42AD-B35F-8FCBEE34C6ED
# item_date                                    20200702.0
# quantity tons                                 82.123794
# customer                                     30200854.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                          1.18
# width                                            1220.0
# material_ref   0000000000000000000000000000000001000812
# product_ref                                   164141591
# delivery date                                20200701.0
# selling_price                                     590.0
#
#                                                  181667  \
# id                 0B812591-B501-4F34-859A-B06381FAEB44
# item_date                                    20200702.0
# quantity tons                                106.783299
# customer                                     30200854.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                          0.96
# width                                            1240.0
# material_ref   0000000000000000000000000000000001000222
# product_ref                                   164141591
# delivery date                                20200701.0
# selling_price                                     602.0
#
#                                                  181668  \
# id                 DE633116-D1DF-4846-982E-55EFC3658A76
# item_date                                    20200702.0
# quantity tons                                102.482422
# customer                                     30200854.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                          0.96
# width                                            1220.0
# material_ref   0000000000000000000000000000000001000777
# product_ref                                   164141591
# delivery date                                20200701.0
# selling_price                                     591.0
#
#                                                  181669  \
# id                 A48374B1-E6DB-45F2-889A-1F9C27C099EB
# item_date                                    20200702.0
# quantity tons                                208.086469
# customer                                     30200854.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                          0.95
# width                                            1500.0
# material_ref   0000000000000000000000000000000001000227
# product_ref                                   164141591
# delivery date                                20200701.0
# selling_price                                     589.0
#
#                                                  181670  \
# id                 91643238-5C7B-4237-9A5F-63AE3D35F320
# item_date                                    20200702.0
# quantity tons                                  4.235594
# customer                                     30200854.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                          0.71
# width                                            1250.0
# material_ref   0000000000000000000000000000000001004216
# product_ref                                   164141591
# delivery date                                20200701.0
# selling_price                                     619.0
#
#                                                  181671  \
# id                 7AFFD323-01D9-4E15-B80D-7D1B03498FC8
# item_date                                    20200702.0
# quantity tons                                     -2000
# customer                                     30200854.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                          0.85
# width                                            1250.0
# material_ref   0000000000000000000000000000000001001149
# product_ref                                   164141591
# delivery date                                20200701.0
# selling_price                                     601.0
#
#                                                  181672
# id                 AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC
# item_date                                    20200702.0
# quantity tons                                406.686538
# customer                                     30200854.0
# country                                            25.0
# status                                              Won
# item type                                             W
# application                                        41.0
# thickness                                          0.71
# width                                            1240.0
# material_ref   0000000000000000000000000000000001005439
# product_ref                                   164141591
# delivery date                                20200701.0
# selling_price                                     607.0
#
# [14 rows x 181673 columns]

# %%
data.shape
# Out:
# (181673, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181671 non-null  object
#  1   item_date      181672 non-null  float64
#  2   quantity tons  181673 non-null  object
#  3   customer       181672 non-null  float64
#  4   country        181645 non-null  float64
#  5   status         181671 non-null  object
#  6   item type      181673 non-null  object
#  7   application    181649 non-null  float64
#  8   thickness      181672 non-null  float64
#  9   width          181673 non-null  float64
#  10  material_ref   103754 non-null  object
#  11  product_ref    181673 non-null  int64
#  12  delivery date  181672 non-null  float64
#  13  selling_price  181672 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 19.4+ MB

# %%
data.isna().sum()
# Out:
# id                   2
# item_date            1
# quantity tons        0
# customer             1
# country             28
# status               2
# item type            0
# application         24
# thickness            1
# width                0
# material_ref     77919
# product_ref          0
# delivery date        1
# selling_price        1
# dtype: int64

# %%
for i in list(data.columns):
    print(f"{i}:_____________{data[i].nunique()}")
# Out:
# id:_____________181671
# item_date:_____________252
# quantity tons:_____________181673
# customer:_____________1169
# country:_____________17
# status:_____________9
# item type:_____________7
# application:_____________30
# thickness:_____________594
# width:_____________1386
# material_ref:_____________16563
# product_ref:_____________33
# delivery date:_____________28
# selling_price:_____________9795

# %%
data[data["id"].isna()==True]['id']
# Out:
# 26        NaN
# 104566    NaN
# Name: id, dtype: object

# %%
data.iloc[26]
# Out:
# id                          NaN
# item_date            20210401.0
# quantity tons          15.92799
# customer             30271717.0
# country                    28.0
# status           To be approved
# item type                     W
# application                10.0
# thickness                   0.8
# width                    1000.0
# material_ref                NaN
# product_ref              611993
# delivery date        20210701.0
# selling_price            1208.0
# Name: 26, dtype: object

# %%
data.describe().T
# Out:
#                   count          mean           std          min         25%  \
# item_date      181672.0  2.020459e+07  4.551119e+03  19950000.00  20200929.0
# customer       181672.0  3.051221e+07  2.433382e+07     12458.00  30196884.0
# country        181645.0  4.489302e+01  2.440421e+01        25.00        26.0
# application    181649.0  2.561581e+01  1.775417e+01         2.00        10.0
# thickness      181672.0  2.564827e+00  6.572321e+00         0.18         0.7
# width          181673.0  1.295287e+03  2.616318e+02         1.00      1180.0
# product_ref    181673.0  4.739679e+08  7.175101e+08    611728.00    611993.0
# delivery date  181672.0  2.020738e+07  2.411059e+04  20190401.00  20201101.0
# selling_price  181672.0  1.918036e+03  3.317956e+05     -1160.00       669.0
#
#                       50%           75%           max
# item_date      20201130.0  2.021020e+07  2.021040e+07
# customer       30205242.0  3.028042e+07  2.147484e+09
# country              30.0  7.800000e+01  1.130000e+02
# application          15.0  4.100000e+01  9.900000e+01
# thickness             1.5  3.000000e+00  2.500000e+03
# width              1250.0  1.500000e+03  2.990000e+03
# product_ref      640665.0  1.332077e+09  1.722208e+09
# delivery date  20210101.0  2.021040e+07  3.031010e+07
# selling_price       812.0  9.530000e+02  1.000010e+08

# %% [markdown]
# # **PRE-PROCESSING**

# %% [markdown]
# # CONVERTING DATE TIME FORMAT

# %%
columns_to_convert_datetime = ['item_date', 'delivery date']
for i in columns_to_convert_datetime:
    data[i] = pd.to_datetime(data[i], format='%Y%m%d', errors='coerce').dt.date
data.head()
# Out:
#                                      id   item_date quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  2021-04-01     54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  2021-04-01    768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158  2021-04-01    386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  2021-04-01    202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  2021-04-01    785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref  product_ref delivery date  \
# 0                               DEQ1 S460MC   1670798778    2021-07-01
# 1  0000000000000000000000000000000000104991   1668701718    2021-04-01
# 2                                  S0380700       628377    2021-01-01
# 3                   DX51D+ZM310MAO 2.3X1317   1668701718    2021-01-01
# 4                           2_S275JR+AR-CL1       640665    2021-03-01
#
#    selling_price
# 0         854.00
# 1        1047.00
# 2         644.33
# 3         768.00
# 4         577.00

# %%
data.dtypes
# Out:
# id                object
# item_date         object
# quantity tons     object
# customer         float64
# country          float64
# status            object
# item type         object
# application      float64
# thickness        float64
# width            float64
# material_ref      object
# product_ref        int64
# delivery date     object
# selling_price    float64
# dtype: object

# %%
data['item_date'] = pd.to_datetime(data['item_date'], format='%Y-%m-%d')
data['delivery date']=pd.to_datetime(data['delivery date'],format='%Y-%m-%d')
data.head()
# Out:
#                                      id  item_date quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01     54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01    768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01    386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01    202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01    785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref  product_ref delivery date  \
# 0                               DEQ1 S460MC   1670798778    2021-07-01
# 1  0000000000000000000000000000000000104991   1668701718    2021-04-01
# 2                                  S0380700       628377    2021-01-01
# 3                   DX51D+ZM310MAO 2.3X1317   1668701718    2021-01-01
# 4                           2_S275JR+AR-CL1       640665    2021-03-01
#
#    selling_price
# 0         854.00
# 1        1047.00
# 2         644.33
# 3         768.00
# 4         577.00

# %%
print(data['item_date'].max())
print(data['item_date'].min())
# Out:
# 2021-04-01 00:00:00
# 2020-07-02 00:00:00

# %%
print(data["delivery date"].max())
print(data['delivery date'].min())
# Out:
# 2022-01-01 00:00:00
# 2019-04-01 00:00:00

# %%
data.dtypes
# Out:
# id                       object
# item_date        datetime64[ns]
# quantity tons            object
# customer                float64
# country                 float64
# status                   object
# item type                object
# application             float64
# thickness               float64
# width                   float64
# material_ref             object
# product_ref               int64
# delivery date    datetime64[ns]
# selling_price           float64
# dtype: object

# %% [markdown]
# # CONVERTING NUMERIC VALUES

# %%
data.dtypes
# Out:
# id                       object
# item_date        datetime64[ns]
# quantity tons            object
# customer                float64
# country                 float64
# status                   object
# item type                object
# application             float64
# thickness               float64
# width                   float64
# material_ref             object
# product_ref               int64
# delivery date    datetime64[ns]
# selling_price           float64
# dtype: object

# %%
columns_to_convert_numeric = ["quantity tons", "customer","country", "application", "thickness", "width", "selling_price"]
for i in columns_to_convert_numeric:
  data[i]=pd.to_numeric(data[i],errors='coerce')
data.head()
# Out:
#                                      id  item_date  quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01     768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01     202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01     785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref  product_ref delivery date  \
# 0                               DEQ1 S460MC   1670798778    2021-07-01
# 1  0000000000000000000000000000000000104991   1668701718    2021-04-01
# 2                                  S0380700       628377    2021-01-01
# 3                   DX51D+ZM310MAO 2.3X1317   1668701718    2021-01-01
# 4                           2_S275JR+AR-CL1       640665    2021-03-01
#
#    selling_price
# 0         854.00
# 1        1047.00
# 2         644.33
# 3         768.00
# 4         577.00

# %%
data.dtypes
# Out:
# id                       object
# item_date        datetime64[ns]
# quantity tons           float64
# customer                float64
# country                 float64
# status                   object
# item type                object
# application             float64
# thickness               float64
# width                   float64
# material_ref             object
# product_ref               int64
# delivery date    datetime64[ns]
# selling_price           float64
# dtype: object

# %%
data.isna().sum()
# Out:
# id                   2
# item_date            3
# quantity tons        1
# customer             1
# country             28
# status               2
# item type            0
# application         24
# thickness            1
# width                0
# material_ref     77919
# product_ref          0
# delivery date        3
# selling_price        1
# dtype: int64

# %% [markdown]
# # DROP ID COLUMN

# %%
data.drop(columns=['id'],inplace=True)
data.head()
# Out:
#    item_date  quantity tons    customer  country status item type  \
# 0 2021-04-01      54.151139  30156308.0     28.0    Won         W
# 1 2021-04-01     768.024839  30202938.0     25.0    Won         W
# 2 2021-04-01     386.127949  30153963.0     30.0    Won        WI
# 3 2021-04-01     202.411065  30349574.0     32.0    Won         S
# 4 2021-04-01     785.526262  30211560.0     28.0    Won         W
#
#    application  thickness   width                              material_ref  \
# 0         10.0       2.00  1500.0                               DEQ1 S460MC
# 1         41.0       0.80  1210.0  0000000000000000000000000000000000104991
# 2         28.0       0.38   952.0                                  S0380700
# 3         59.0       2.30  1317.0                   DX51D+ZM310MAO 2.3X1317
# 4         10.0       4.00  2000.0                           2_S275JR+AR-CL1
#
#    product_ref delivery date  selling_price
# 0   1670798778    2021-07-01         854.00
# 1   1668701718    2021-04-01        1047.00
# 2       628377    2021-01-01         644.33
# 3   1668701718    2021-01-01         768.00
# 4       640665    2021-03-01         577.00

# %% [markdown]
# # MATERIAL_REF COLUMN

# %%
data['material_ref'] = data['material_ref'].apply(lambda x: np.nan if str(x).startswith('00000') else x)
data.head()
# Out:
#    item_date  quantity tons    customer  country status item type  \
# 0 2021-04-01      54.151139  30156308.0     28.0    Won         W
# 1 2021-04-01     768.024839  30202938.0     25.0    Won         W
# 2 2021-04-01     386.127949  30153963.0     30.0    Won        WI
# 3 2021-04-01     202.411065  30349574.0     32.0    Won         S
# 4 2021-04-01     785.526262  30211560.0     28.0    Won         W
#
#    application  thickness   width             material_ref  product_ref  \
# 0         10.0       2.00  1500.0              DEQ1 S460MC   1670798778
# 1         41.0       0.80  1210.0                      NaN   1668701718
# 2         28.0       0.38   952.0                 S0380700       628377
# 3         59.0       2.30  1317.0  DX51D+ZM310MAO 2.3X1317   1668701718
# 4         10.0       4.00  2000.0          2_S275JR+AR-CL1       640665
#
#   delivery date  selling_price
# 0    2021-07-01         854.00
# 1    2021-04-01        1047.00
# 2    2021-01-01         644.33
# 3    2021-01-01         768.00
# 4    2021-03-01         577.00

# %%
data.drop(columns=['material_ref'],inplace=True)
data.head()
# Out:
#    item_date  quantity tons    customer  country status item type  \
# 0 2021-04-01      54.151139  30156308.0     28.0    Won         W
# 1 2021-04-01     768.024839  30202938.0     25.0    Won         W
# 2 2021-04-01     386.127949  30153963.0     30.0    Won        WI
# 3 2021-04-01     202.411065  30349574.0     32.0    Won         S
# 4 2021-04-01     785.526262  30211560.0     28.0    Won         W
#
#    application  thickness   width  product_ref delivery date  selling_price
# 0         10.0       2.00  1500.0   1670798778    2021-07-01         854.00
# 1         41.0       0.80  1210.0   1668701718    2021-04-01        1047.00
# 2         28.0       0.38   952.0       628377    2021-01-01         644.33
# 3         59.0       2.30  1317.0   1668701718    2021-01-01         768.00
# 4         10.0       4.00  2000.0       640665    2021-03-01         577.00

# %%
data.isna().sum()
# Out:
# item_date         3
# quantity tons     1
# customer          1
# country          28
# status            2
# item type         0
# application      24
# thickness         1
# width             0
# product_ref       0
# delivery date     3
# selling_price     1
# dtype: int64

# %%
data.describe().T
# Out:
#                   count                           mean                  min  \
# item_date        181670  2020-11-26 22:56:58.127374080  2020-07-02 00:00:00
# quantity tons  181672.0                    5874.925754              -2000.0
# customer       181672.0                30512209.027968              12458.0
# country        181645.0                      44.893022                 25.0
# application    181649.0                      25.615809                  2.0
# thickness      181672.0                       2.564827                 0.18
# width          181673.0                    1295.286724                  1.0
# product_ref    181673.0               473967910.724318             611728.0
# delivery date    181670  2021-01-25 22:44:26.223372032  2019-04-01 00:00:00
# selling_price  181672.0                    1918.035505              -1160.0
#
#                                25%                  50%                  75%  \
# item_date      2020-09-29 00:00:00  2020-11-30 00:00:00  2021-02-03 00:00:00
# quantity tons            10.970298            30.364635            67.160612
# customer                30196884.0           30205242.0           30280416.0
# country                       26.0                 30.0                 78.0
# application                   10.0                 15.0                 41.0
# thickness                      0.7                  1.5                  3.0
# width                       1180.0               1250.0               1500.0
# product_ref               611993.0             640665.0         1332077137.0
# delivery date  2020-11-01 00:00:00  2021-01-01 00:00:00  2021-04-01 00:00:00
# selling_price                669.0                812.0                953.0
#
#                                max               std
# item_date      2021-04-01 00:00:00               NaN
# quantity tons         1000000000.0    2349081.241674
# customer              2147483647.0   24333815.584025
# country                      113.0         24.404214
# application                   99.0         17.754175
# thickness                   2500.0          6.572321
# width                       2990.0        261.631754
# product_ref           1722207579.0  717510064.710402
# delivery date  2022-01-01 00:00:00               NaN
# selling_price          100001015.0     331795.642555

# %% [markdown]
# #  CHANGE TH NEGATIVE VALUES IN THE COLUMNS

# %% [markdown]
# # FILLNA VALUES

# %% [markdown]
# # WITH MEDIEN

# %%
#numerical datatype using median
data['quantity tons'].fillna(data['quantity tons'].median(), inplace=True)
data['customer'].fillna(data['customer'].median(), inplace=True)
data['country'].fillna(data['country'].median(), inplace=True)
data['application'].fillna(data['application'].median(), inplace=True)
data['thickness'].fillna(data['thickness'].median(), inplace=True)
data['selling_price'].fillna(data['selling_price'].median(), inplace=True)

# %%
# object datatype using mode
data['item_date'].fillna(data['item_date'].mode().iloc[0], inplace=True)
data['status'].fillna(data['status'].mode().iloc[0], inplace=True)
data['delivery date'].fillna(data['delivery date'].mode().iloc[0], inplace=True)

# %%
data["country"]=data["country"].astype('int64')

# %%
data.isna().sum()
# Out:
# item_date        0
# quantity tons    0
# customer         0
# country          0
# status           0
# item type        0
# application      0
# thickness        0
# width            0
# product_ref      0
# delivery date    0
# selling_price    0
# dtype: int64

# %%
data.dtypes
# Out:
# item_date        datetime64[ns]
# quantity tons           float64
# customer                float64
# country                   int64
# status                   object
# item type                object
# application             float64
# thickness               float64
# width                   float64
# product_ref               int64
# delivery date    datetime64[ns]
# selling_price           float64
# dtype: object

# %%
data.to_csv('clean_copper_data.csv',index=False) # Not to write the indices for csv file

# %% [markdown]
# ## **EDA**

# %% [markdown]
# TO VISUALIZE OUTLIERS AND SKEWNESS

# %%
# BEFORE TREATING

eda_data=data.copy(deep = True)

# %%
eda_data.dtypes
# Out:
# item_date        datetime64[ns]
# quantity tons           float64
# customer                float64
# country                   int64
# status                   object
# item type                object
# application             float64
# thickness               float64
# width                   float64
# product_ref               int64
# delivery date    datetime64[ns]
# selling_price           float64
# dtype: object

# %% [markdown]
# # Using Boxplot and Distplot

# %%
# Create a figure with 6 subplots
fig, axes = plt.subplots(7, 2, figsize=(10,20))

sns.boxplot(ax=axes[0, 0], data=eda_data['quantity tons'])      #quantity tons
axes[0, 0].set_title('quantity tons - Outliers')
sns.distplot(ax=axes[0, 1], a=eda_data['quantity tons'])
axes[0, 1].set_title('quantity tons - Skewness')

sns.boxplot(ax=axes[1, 0], data=eda_data['customer'])          #customer
axes[1, 0].set_title('customer - Outliers')
sns.distplot(ax=axes[1, 1], a=eda_data['customer'])
axes[1, 1].set_title('customer - Skewness')

sns.boxplot(ax=axes[2, 0], data=eda_data['country'])           #country
axes[2, 0].set_title('country - Outliers')
sns.distplot(ax=axes[2, 1], a=eda_data['country'])
axes[2, 1].set_title('country - Skewness')

sns.boxplot(ax=axes[3, 0], data=eda_data['application'])       #application
axes[3, 0].set_title('application - Outliers')
sns.distplot(ax=axes[3, 1], a=eda_data['application'])
axes[3, 1].set_title('application - Skewness')

sns.boxplot(ax=axes[4, 0], data=eda_data['thickness'])        #thickness
axes[4, 0].set_title('thickness - Outliers')
sns.distplot(ax=axes[4, 1], a=eda_data['thickness'])
axes[4, 1].set_title('thickness - Skewness')

sns.boxplot(ax=axes[5, 0], data=eda_data['width'])            #width
axes[5, 0].set_title('width - Outliers')
sns.distplot(ax=axes[5, 1], a=eda_data['width'])
axes[5, 1].set_title('width - Skewness')

sns.boxplot(ax=axes[6, 0], data=eda_data['selling_price'])   #selling_price
axes[6, 0].set_title('selling_price - Outliers')
sns.distplot(ax=axes[6, 1], a=eda_data['selling_price'])
axes[6, 1].set_title('selling_price - Skewness')

plt.tight_layout()
plt.show()

# %% [markdown]
# # USING VIOLIN PLOT

# %%
def plot(eda_data, column):
    plt.figure(figsize=(10,5))
    plt.subplot(1,1,1)
    sns.violinplot(data=eda_data, x=column)
    plt.title(f'Violin Plot for {column}')
    plt.show()

# %%
for i in ['quantity tons', 'customer', 'country',  'application', 'thickness', 'width', 'selling_price']:
    plot(eda_data, i)

# %%
out_skew_data=eda_data.copy(True)

# %%
skewed_columns = ['quantity tons', 'thickness', 'width', 'selling_price']
for column in skewed_columns:
    neg = (out_skew_data[column] <= 0)
    print(f'{column} : {neg.sum()} ')
    out_skew_data.loc[neg,column] = np.nan
# Out:
# quantity tons : 4
# thickness : 0
# width : 0
# selling_price : 7

# %%
out_skew_data
# Out:
#         item_date  quantity tons    customer  country status item type  \
# 0      2021-04-01      54.151139  30156308.0       28    Won         W
# 1      2021-04-01     768.024839  30202938.0       25    Won         W
# 2      2021-04-01     386.127949  30153963.0       30    Won        WI
# 3      2021-04-01     202.411065  30349574.0       32    Won         S
# 4      2021-04-01     785.526262  30211560.0       28    Won         W
# ...           ...            ...         ...      ...    ...       ...
# 181668 2020-07-02     102.482422  30200854.0       25    Won         W
# 181669 2020-07-02     208.086469  30200854.0       25    Won         W
# 181670 2020-07-02       4.235594  30200854.0       25    Won         W
# 181671 2020-07-02            NaN  30200854.0       25    Won         W
# 181672 2020-07-02     406.686538  30200854.0       25    Won         W
#
#         application  thickness   width  product_ref delivery date  \
# 0              10.0       2.00  1500.0   1670798778    2021-07-01
# 1              41.0       0.80  1210.0   1668701718    2021-04-01
# 2              28.0       0.38   952.0       628377    2021-01-01
# 3              59.0       2.30  1317.0   1668701718    2021-01-01
# 4              10.0       4.00  2000.0       640665    2021-03-01
# ...             ...        ...     ...          ...           ...
# 181668         41.0       0.96  1220.0    164141591    2020-07-01
# 181669         41.0       0.95  1500.0    164141591    2020-07-01
# 181670         41.0       0.71  1250.0    164141591    2020-07-01
# 181671         41.0       0.85  1250.0    164141591    2020-07-01
# 181672         41.0       0.71  1240.0    164141591    2020-07-01
#
#         selling_price
# 0              854.00
# 1             1047.00
# 2              644.33
# 3              768.00
# 4              577.00
# ...               ...
# 181668         591.00
# 181669         589.00
# 181670         619.00
# 181671         601.00
# 181672         607.00
#
# [181673 rows x 12 columns]

# %%
out_skew_data.isna().sum()
# Out:
# item_date        0
# quantity tons    4
# customer         0
# country          0
# status           0
# item type        0
# application      0
# thickness        0
# width            0
# product_ref      0
# delivery date    0
# selling_price    7
# dtype: int64

# %%
out_skew_data['quantity tons'].fillna(out_skew_data['quantity tons'].mean(), inplace = True)   # df['A'].fillna(df['A'].mean(), inplace=True) 
out_skew_data['selling_price'].interpolate(method ='linear',inplace = True)           #   df_1["beds"].interpolate(method = 'linear',inplace= True)

# %%
out_skew_data.isna().sum()
# Out:
# item_date        0
# quantity tons    0
# customer         0
# country          0
# status           0
# item type        0
# application      0
# thickness        0
# width            0
# product_ref      0
# delivery date    0
# selling_price    0
# dtype: int64

# %%
out_skew_data_1=out_skew_data.copy(True)

# %%
out_skew_data_1=out_skew_data_1.drop(['item_date','delivery date','status','item type'],axis=1)

# %%
out_skew_data_1.skew()
# Out:
# quantity tons    424.690816
# customer          86.985308
# country            0.753835
# application        0.724564
# thickness        303.447571
# width              0.374597
# product_ref        1.015216
# selling_price    301.388088
# dtype: float64

# %%
print(out_skew_data['item_date'].max())
print(out_skew_data['item_date'].min())
print(out_skew_data["delivery date"].max())
print(out_skew_data['delivery date'].min())
# Out:
# 2021-04-01 00:00:00
# 2020-07-02 00:00:00
# 2022-01-01 00:00:00
# 2019-04-01 00:00:00

# %% [markdown]
# # IQR-Inter Quartile Range

# %%
outlier_columns = ['quantity tons', 'thickness', 'width', 'selling_price']
before_stats = out_skew_data[outlier_columns].describe()

# Iterate over outlier columns and remove outliers
for column in outlier_columns:
    Q1 = out_skew_data[column].quantile(0.25)
    Q3 = out_skew_data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    out_skew_data[column] = out_skew_data[column].clip(lower_bound, upper_bound)

# Calculate summary statistics after removing outliers
after_stats = out_skew_data[outlier_columns].describe()

# Compare the statistics before and after outlier removal
print("Summary statistics before removing outliers:")
print(before_stats)
print("\nSummary statistics after removing outliers:")
print(after_stats)
# Out:
# Summary statistics before removing outliers:
#        quantity tons      thickness          width  selling_price
# count   1.816730e+05  181673.000000  181673.000000   1.816730e+05
# mean    5.875034e+03       2.564822    1295.286724   1.918079e+03
# std     2.349075e+06       6.572303     261.631754   3.317947e+05
# min     1.000000e-05       0.180000       1.000000   1.000000e-01
# 25%     1.097167e+01       0.700000    1180.000000   6.690000e+02
# 50%     3.036536e+01       1.500000    1250.000000   8.120000e+02
# 75%     6.716643e+01       3.000000    1500.000000   9.530000e+02
# max     1.000000e+09    2500.000000    2990.000000   1.000010e+08
#
# Summary statistics after removing outliers:
#        quantity tons      thickness          width  selling_price
# count  181673.000000  181673.000000  181673.000000  181673.000000
# mean       49.180015       2.245427    1297.045583     819.078237
# std        47.997977       1.890707     248.961933     209.129161
# min         0.000010       0.180000     700.000000     243.000000
# 25%        10.971669       0.700000    1180.000000     669.000000
# 50%        30.365363       1.500000    1250.000000     812.000000
# 75%        67.166431       3.000000    1500.000000     953.000000
# max       151.458575       6.450000    1980.000000    1379.000000

# %% [markdown]
# # AFTER TREATING OUTLIERS AND SKEWNESS

# %%
out_skew_data.plot(kind='box',subplots=True,layout=(4,4),figsize=(18,15))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
outlier_columns = ['quantity tons', 'thickness', 'width', 'selling_price']

# Plot the histograms of the transformed data
fig, axes = plt.subplots(1, 4,figsize=(15, 5))
axes = axes.flatten()
for i, column in enumerate(outlier_columns):
    sns.distplot(out_skew_data[column], kde=True, ax=axes[i])
    axes[i].set_title(f"Transformed {column}")

plt.tight_layout() #for neat plots without overlapping 
plt.show()

# %%
out_skew_data_1.skew()
# Out:
# quantity tons    424.690816
# customer          86.985308
# country            0.753835
# application        0.724564
# thickness        303.447571
# width              0.374597
# product_ref        1.015216
# selling_price    301.388088
# dtype: float64

# %%
# Here are some guidelines for interpreting skewness values:

# Skewness value close to 0: The distribution is approximately symmetrical.
# Skewness value between -0.5 and -1 or between 0.5 and 1: The distribution is moderately skewed.
# Skewness value less than -1 or greater than 1: The distribution is highly skewed.

# %% [markdown]
# # FEATURE ENGINEERING
#
#
# *   Label encoding
# *   Feature selection
# *   Standardize / normalize data

# %%
model_data=out_skew_data.copy(True)
model_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_date      181673 non-null  datetime64[ns]
#  1   quantity tons  181673 non-null  float64
#  2   customer       181673 non-null  float64
#  3   country        181673 non-null  int64
#  4   status         181673 non-null  object
#  5   item type      181673 non-null  object
#  6   application    181673 non-null  float64
#  7   thickness      181673 non-null  float64
#  8   width          181673 non-null  float64
#  9   product_ref    181673 non-null  int64
#  10  delivery date  181673 non-null  datetime64[ns]
#  11  selling_price  181673 non-null  float64
# dtypes: datetime64[ns](2), float64(6), int64(2), object(2)
# memory usage: 16.6+ MB

# %%
model_data['delivery_time_taken']=(model_data['item_date']-model_data['delivery date']).abs().dt.days
model_data.head()
# Out:
#    item_date  quantity tons    customer  country status item type  \
# 0 2021-04-01      54.151139  30156308.0       28    Won         W
# 1 2021-04-01     151.458575  30202938.0       25    Won         W
# 2 2021-04-01     151.458575  30153963.0       30    Won        WI
# 3 2021-04-01     151.458575  30349574.0       32    Won         S
# 4 2021-04-01     151.458575  30211560.0       28    Won         W
#
#    application  thickness   width  product_ref delivery date  selling_price  \
# 0         10.0       2.00  1500.0   1670798778    2021-07-01         854.00
# 1         41.0       0.80  1210.0   1668701718    2021-04-01        1047.00
# 2         28.0       0.38   952.0       628377    2021-01-01         644.33
# 3         59.0       2.30  1317.0   1668701718    2021-01-01         768.00
# 4         10.0       4.00  1980.0       640665    2021-03-01         577.00
#
#    delivery_time_taken
# 0                   91
# 1                    0
# 2                   90
# 3                   90
# 4                   31

# %%
x=model_data[['application','thickness','width','selling_price','quantity tons','country','customer','product_ref','delivery_time_taken']]

# %%
x
# Out:
#         application  thickness   width  selling_price  quantity tons  country  \
# 0              10.0       2.00  1500.0         854.00      54.151139       28
# 1              41.0       0.80  1210.0        1047.00     151.458575       25
# 2              28.0       0.38   952.0         644.33     151.458575       30
# 3              59.0       2.30  1317.0         768.00     151.458575       32
# 4              10.0       4.00  1980.0         577.00     151.458575       28
# ...             ...        ...     ...            ...            ...      ...
# 181668         41.0       0.96  1220.0         591.00     102.482422       25
# 181669         41.0       0.95  1500.0         589.00     151.458575       25
# 181670         41.0       0.71  1250.0         619.00       4.235594       25
# 181671         41.0       0.85  1250.0         601.00     151.458575       25
# 181672         41.0       0.71  1240.0         607.00     151.458575       25
#
#           customer  product_ref  delivery_time_taken
# 0       30156308.0   1670798778                   91
# 1       30202938.0   1668701718                    0
# 2       30153963.0       628377                   90
# 3       30349574.0   1668701718                   90
# 4       30211560.0       640665                   31
# ...            ...          ...                  ...
# 181668  30200854.0    164141591                    1
# 181669  30200854.0    164141591                    1
# 181670  30200854.0    164141591                    1
# 181671  30200854.0    164141591                    1
# 181672  30200854.0    164141591                    1
#
# [181673 rows x 9 columns]

# %%
model_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   item_date            181673 non-null  datetime64[ns]
#  1   quantity tons        181673 non-null  float64
#  2   customer             181673 non-null  float64
#  3   country              181673 non-null  int64
#  4   status               181673 non-null  object
#  5   item type            181673 non-null  object
#  6   application          181673 non-null  float64
#  7   thickness            181673 non-null  float64
#  8   width                181673 non-null  float64
#  9   product_ref          181673 non-null  int64
#  10  delivery date        181673 non-null  datetime64[ns]
#  11  selling_price        181673 non-null  float64
#  12  delivery_time_taken  181673 non-null  int64
# dtypes: datetime64[ns](2), float64(6), int64(3), object(2)
# memory usage: 18.0+ MB

# %%
num=model_data.select_dtypes(include=np.number)
num
# Out:
#         quantity tons    customer  country  application  thickness   width  \
# 0           54.151139  30156308.0       28         10.0       2.00  1500.0
# 1          151.458575  30202938.0       25         41.0       0.80  1210.0
# 2          151.458575  30153963.0       30         28.0       0.38   952.0
# 3          151.458575  30349574.0       32         59.0       2.30  1317.0
# 4          151.458575  30211560.0       28         10.0       4.00  1980.0
# ...               ...         ...      ...          ...        ...     ...
# 181668     102.482422  30200854.0       25         41.0       0.96  1220.0
# 181669     151.458575  30200854.0       25         41.0       0.95  1500.0
# 181670       4.235594  30200854.0       25         41.0       0.71  1250.0
# 181671     151.458575  30200854.0       25         41.0       0.85  1250.0
# 181672     151.458575  30200854.0       25         41.0       0.71  1240.0
#
#         product_ref  selling_price  delivery_time_taken
# 0        1670798778         854.00                   91
# 1        1668701718        1047.00                    0
# 2            628377         644.33                   90
# 3        1668701718         768.00                   90
# 4            640665         577.00                   31
# ...             ...            ...                  ...
# 181668    164141591         591.00                    1
# 181669    164141591         589.00                    1
# 181670    164141591         619.00                    1
# 181671    164141591         601.00                    1
# 181672    164141591         607.00                    1
#
# [181673 rows x 9 columns]

# %% [markdown]
# # Correlation

# %%
# correlation matrix (ranges from 1 to -1)
corrm=num.corr()
#corrm.to_csv('corrm.csv')
corrm
# Out:
#                      quantity tons  customer   country  application  \
# quantity tons             1.000000 -0.001917 -0.090087     0.095513
# customer                 -0.001917  1.000000 -0.006669    -0.006869
# country                  -0.090087 -0.006669  1.000000    -0.019304
# application               0.095513 -0.006869 -0.019304     1.000000
# thickness                 0.002737  0.021805 -0.055997    -0.163476
# width                     0.010407  0.009585  0.053867    -0.198878
# product_ref               0.051458 -0.007716 -0.147326    -0.131784
# selling_price            -0.041863 -0.026030 -0.021719     0.129912
# delivery_time_taken       0.067631 -0.001515 -0.240407    -0.167836
#
#                      thickness     width  product_ref  selling_price  \
# quantity tons         0.002737  0.010407     0.051458      -0.041863
# customer              0.021805  0.009585    -0.007716      -0.026030
# country              -0.055997  0.053867    -0.147326      -0.021719
# application          -0.163476 -0.198878    -0.131784       0.129912
# thickness             1.000000  0.419061     0.155786      -0.363804
# width                 0.419061  1.000000    -0.024106      -0.173305
# product_ref           0.155786 -0.024106     1.000000      -0.077774
# selling_price        -0.363804 -0.173305    -0.077774       1.000000
# delivery_time_taken   0.084544  0.038791     0.161776       0.274218
#
#                      delivery_time_taken
# quantity tons                   0.067631
# customer                       -0.001515
# country                        -0.240407
# application                    -0.167836
# thickness                       0.084544
# width                           0.038791
# product_ref                     0.161776
# selling_price                   0.274218
# delivery_time_taken             1.000000

# %% [markdown]
# # Heatmap

# %%
# visualize correlation matrix in Seaborn using a heatmap
plt.figure(figsize=(16,6))
sns.heatmap(corrm,annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# # FINDING UNIQUE VALUE

# %%
model_data['country'] = model_data['country'].astype(str)
country=model_data['country'].unique()
status=model_data['status'].unique()
item=model_data['item type'].unique()
print(country)
print(status)
print(item)
# Out:
# ['28' '25' '30' '32' '38' '78' '27' '77' '113' '79' '26' '39' '40' '84'
#  '80' '107' '89']
# ['Won' 'Draft' 'To be approved' 'Lost' 'Not lost for AM' 'Wonderful'
#  'Revised' 'Offered' 'Offerable']
# ['W' 'WI' 'S' 'Others' 'PL' 'IPL' 'SLAWR']

# %% [markdown]
# # ENCODE THE CATEGORICAL COLUMN

# %% [markdown]
# ## country

# %%
from sklearn.preprocessing import OrdinalEncoder

encode=OrdinalEncoder()
model_data["country"] = encode.fit_transform(model_data[["country"]])
transformed_country=model_data["country"].unique()

transformed_country
# Out:
# array([ 5.,  2.,  6.,  7.,  8., 12.,  4., 11.,  1., 13.,  3.,  9., 10.,
#        15., 14.,  0., 16.])

# %% [markdown]
# ## status

# %%
encode=OrdinalEncoder()
model_data['status'] = encode.fit_transform(model_data[['status']])
transformed_status=model_data['status'].unique()

transformed_status
# Out:
# array([7., 0., 6., 1., 2., 8., 5., 4., 3.])

# %% [markdown]
# ## item type

# %%
encode=OrdinalEncoder()
model_data["item type"] = encode.fit_transform(model_data[["item type"]])
transformed_item=model_data["item type"].unique()

transformed_item
# Out:
# array([5., 6., 3., 1., 2., 0., 4.])

# %%
model_data.head()
# Out:
#    item_date  quantity tons    customer  country  status  item type  \
# 0 2021-04-01      54.151139  30156308.0      5.0     7.0        5.0
# 1 2021-04-01     151.458575  30202938.0      2.0     7.0        5.0
# 2 2021-04-01     151.458575  30153963.0      6.0     7.0        6.0
# 3 2021-04-01     151.458575  30349574.0      7.0     7.0        3.0
# 4 2021-04-01     151.458575  30211560.0      5.0     7.0        5.0
#
#    application  thickness   width  product_ref delivery date  selling_price  \
# 0         10.0       2.00  1500.0   1670798778    2021-07-01         854.00
# 1         41.0       0.80  1210.0   1668701718    2021-04-01        1047.00
# 2         28.0       0.38   952.0       628377    2021-01-01         644.33
# 3         59.0       2.30  1317.0   1668701718    2021-01-01         768.00
# 4         10.0       4.00  1980.0       640665    2021-03-01         577.00
#
#    delivery_time_taken
# 0                   91
# 1                    0
# 2                   90
# 3                   90
# 4                   31

# %%
co=model_data.corr()
co
# Out:
#                      item_date  quantity tons  customer   country    status  \
# item_date             1.000000      -0.004176 -0.003787 -0.017767  0.080484
# quantity tons        -0.004176       1.000000 -0.001917 -0.088918 -0.055863
# customer             -0.003787      -0.001917  1.000000 -0.002373 -0.020449
# country              -0.017767      -0.088918 -0.002373  1.000000  0.086433
# status                0.080484      -0.055863 -0.020449  0.086433  1.000000
# item type             0.077163      -0.244979 -0.010901  0.152515  0.242838
# application          -0.008445       0.095513 -0.006869 -0.045995  0.132781
# thickness             0.004442       0.002737  0.021805 -0.043305 -0.127171
# width                 0.005957       0.010407  0.009585  0.051926 -0.092670
# product_ref           0.045250       0.051458 -0.007716 -0.146454 -0.069740
# delivery date         0.920098       0.016051 -0.002908 -0.093006 -0.054812
# selling_price         0.556567      -0.041863 -0.026030 -0.038018  0.122203
# delivery_time_taken   0.438562       0.067631 -0.001515 -0.223455 -0.260809
#
#                      item type  application  thickness     width  product_ref  \
# item_date             0.077163    -0.008445   0.004442  0.005957     0.045250
# quantity tons        -0.244979     0.095513   0.002737  0.010407     0.051458
# customer             -0.010901    -0.006869   0.021805  0.009585    -0.007716
# country               0.152515    -0.045995  -0.043305  0.051926    -0.146454
# status                0.242838     0.132781  -0.127171 -0.092670    -0.069740
# item type             1.000000     0.169124  -0.076785 -0.092094    -0.089501
# application           0.169124     1.000000  -0.163476 -0.198878    -0.131784
# thickness            -0.076785    -0.163476   1.000000  0.419061     0.155786
# width                -0.092094    -0.198878   0.419061  1.000000    -0.024106
# product_ref          -0.089501    -0.131784   0.155786 -0.024106     1.000000
# delivery date         0.005805    -0.078509   0.042496  0.026823     0.096195
# selling_price         0.096077     0.129912  -0.363804 -0.173305    -0.077774
# delivery_time_taken  -0.142579    -0.167836   0.084544  0.038791     0.161776
#
#                      delivery date  selling_price  delivery_time_taken
# item_date                 0.920098       0.556567             0.438562
# quantity tons             0.016051      -0.041863             0.067631
# customer                 -0.002908      -0.026030            -0.001515
# country                  -0.093006      -0.038018            -0.223455
# status                   -0.054812       0.122203            -0.260809
# item type                 0.005805       0.096077            -0.142579
# application              -0.078509       0.129912            -0.167836
# thickness                 0.042496      -0.363804             0.084544
# width                     0.026823      -0.173305             0.038791
# product_ref               0.096195      -0.077774             0.161776
# delivery date             1.000000       0.529955             0.689904
# selling_price             0.529955       1.000000             0.274218
# delivery_time_taken       0.689904       0.274218             1.000000

# %%
plt.figure(figsize=(16,6))
sns.heatmap(co,annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# # After encoding the Categorical data

# %%
for i, j in zip(status, transformed_status):
    print('After encoding :',i,'----- encoded :',j)
# Out:
# After encoding : Won ----- encoded : 7.0
# After encoding : Draft ----- encoded : 0.0
# After encoding : To be approved ----- encoded : 6.0
# After encoding : Lost ----- encoded : 1.0
# After encoding : Not lost for AM ----- encoded : 2.0
# After encoding : Wonderful ----- encoded : 8.0
# After encoding : Revised ----- encoded : 5.0
# After encoding : Offered ----- encoded : 4.0
# After encoding : Offerable ----- encoded : 3.0

# %%
for i,j in zip(item, transformed_item):
    print('After encoding :',i,'----- encoded :',j)
# Out:
# After encoding : W ----- encoded : 5.0
# After encoding : WI ----- encoded : 6.0
# After encoding : S ----- encoded : 3.0
# After encoding : Others ----- encoded : 1.0
# After encoding : PL ----- encoded : 2.0
# After encoding : IPL ----- encoded : 0.0
# After encoding : SLAWR ----- encoded : 4.0

# %%
for i,j in zip(country, transformed_country):
    print('After encoding :',i,'----- encoded :',j)
# Out:
# After encoding : 28 ----- encoded : 5.0
# After encoding : 25 ----- encoded : 2.0
# After encoding : 30 ----- encoded : 6.0
# After encoding : 32 ----- encoded : 7.0
# After encoding : 38 ----- encoded : 8.0
# After encoding : 78 ----- encoded : 12.0
# After encoding : 27 ----- encoded : 4.0
# After encoding : 77 ----- encoded : 11.0
# After encoding : 113 ----- encoded : 1.0
# After encoding : 79 ----- encoded : 13.0
# After encoding : 26 ----- encoded : 3.0
# After encoding : 39 ----- encoded : 9.0
# After encoding : 40 ----- encoded : 10.0
# After encoding : 84 ----- encoded : 15.0
# After encoding : 80 ----- encoded : 14.0
# After encoding : 107 ----- encoded : 0.0
# After encoding : 89 ----- encoded : 16.0

# %% [markdown]
# # **Pickle**

# %%
import pickle

file_path='country.pkl'
file_path2='status.pkl'
file_path3='item type.pkl'

with open(file_path, 'wb') as file:
    pickle.dump(transformed_country, file)
with open(file_path2, 'wb') as file:
    pickle.dump(transformed_status, file)
with open(file_path3, 'wb') as file:
    pickle.dump(transformed_item, file)

print(f'Pickle file created: {file_path}, {file_path2},{file_path3}')
# Out:
# Pickle file created: country.pkl, status.pkl,item type.pkl

# %% [markdown]
# ## Load

# %%
import pickle
with open('status.pkl', 'rb') as file:
    encode_status = pickle.load(file)

encode_status
# Out:
# array([7., 0., 6., 1., 2., 8., 5., 4., 3.])

# %% [markdown]
# # REGRESSION MODEL FOR FINDING SELLING PRICE

# %%
category_col=['status', 'item type','country']
encoder= OrdinalEncoder()
for i in category_col:
    print(i)
    model_data[i] = encoder.fit_transform(model_data[[i]])
    print(model_data[i].unique())
# Out:
# status
# [7. 0. 6. 1. 2. 8. 5. 4. 3.]
# item type
# [5. 6. 3. 1. 2. 0. 4.]
# country
# [ 5.  2.  6.  7.  8. 12.  4. 11.  1. 13.  3.  9. 10. 15. 14.  0. 16.]

# %%
model_data.head()
# Out:
#    item_date  quantity tons    customer  country  status  item type  \
# 0 2021-04-01      54.151139  30156308.0      5.0     7.0        5.0
# 1 2021-04-01     151.458575  30202938.0      2.0     7.0        5.0
# 2 2021-04-01     151.458575  30153963.0      6.0     7.0        6.0
# 3 2021-04-01     151.458575  30349574.0      7.0     7.0        3.0
# 4 2021-04-01     151.458575  30211560.0      5.0     7.0        5.0
#
#    application  thickness   width  product_ref delivery date  selling_price  \
# 0         10.0       2.00  1500.0   1670798778    2021-07-01         854.00
# 1         41.0       0.80  1210.0   1668701718    2021-04-01        1047.00
# 2         28.0       0.38   952.0       628377    2021-01-01         644.33
# 3         59.0       2.30  1317.0   1668701718    2021-01-01         768.00
# 4         10.0       4.00  1980.0       640665    2021-03-01         577.00
#
#    delivery_time_taken
# 0                   91
# 1                    0
# 2                   90
# 3                   90
# 4                   31

# %%
X = model_data[[ 'quantity tons','thickness','width','country','status','item type', 'application','product_ref','delivery_time_taken']].values
y = model_data[['selling_price']].values

scaler = StandardScaler().fit(X)
X = scaler.transform(X)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.27, random_state=27)

# %%
import pickle
file_path6='scaling.pkl'
with open(file_path6, 'wb') as file:
    pickle.dump(scaler, file)
print(f'Pickle file created: {file_path6}')
# Out:
# Pickle file created: scaling.pkl

# %%
# Create an instance of each regression model
et_model = ExtraTreesRegressor()               # Extra Tree Regressor
xgb_model = XGBRegressor()                     # Extreme Gradient Boost Regressor
dt_model = DecisionTreeRegressor()             # Decision Tree Regressor
sgd_model = SGDRegressor() # Support Vector Machine

# Train the models
et_model.fit(X_train, y_train)
xgb_model.fit(X_train, y_train)
dt_model.fit(X_train, y_train)
sgd_model.fit(X_train, y_train)

# Make predictions on the test set
et_preds = et_model.predict(X_test)
xgb_preds = xgb_model.predict(X_test)
dt_preds = dt_model.predict(X_test)
sgd_preds = sgd_model.predict(X_test)

# Evaluate the models
et_mse = mean_squared_error(y_test, et_preds)
et_mae = mean_absolute_error(y_test, et_preds)
et_r2 = r2_score(y_test, et_preds)

xgb_mse = mean_squared_error(y_test, xgb_preds)
xgb_mae = mean_absolute_error(y_test, xgb_preds)
xgb_r2 = r2_score(y_test, xgb_preds)

dt_mse = mean_squared_error(y_test, dt_preds)
dt_mae = mean_absolute_error(y_test, dt_preds)
dt_r2 = r2_score(y_test, dt_preds)

sgd_mse = mean_squared_error(y_test, sgd_preds)
sgd_mae = mean_absolute_error(y_test, sgd_preds)
sgd_r2 = r2_score(y_test, sgd_preds)

# %%
# Print the evaluation results
print(f"Extra Trees Regressor - MSE: {et_mse}, MAE: {et_mae}, R^2: {et_r2}")
print(f"XGB Regressor - MSE: {xgb_mse}, MAE: {xgb_mae}, R^2: {xgb_r2}")
print(f"Decision Tree Regressor - MSE: {dt_mse}, MAE: {dt_mae}, R^2: {dt_r2}")
print(f"SGD - MSE: {sgd_mse}, MAE: {sgd_mae}, R^2: {sgd_r2}")
# Out:
# Extra Trees Regressor - MSE: 4456.326844058554, MAE: 40.68204965501062, R^2: 0.8976936987926045
# XGB Regressor - MSE: 8156.388482681079, MAE: 68.117532933439, R^2: 0.8127493861931961
# Decision Tree Regressor - MSE: 7734.790945098577, MAE: 47.288719192326745, R^2: 0.8224282284723969
# SGD - MSE: 31717.150246414723, MAE: 136.44931313234255, R^2: 0.27185225857565387

# %%
models = ['ExtraTreeRegressor', 'DecisionTreeRegressor', 'XGBRegressor','SGDRegressor']
score = [et_r2, dt_r2, xgb_r2,sgd_r2]

fig=px.bar(x=models, y=score,title='R_2 of Regression Models')
fig.show()

print("FINDING BEST FIT MODEL FOR EVALUATION BASED ON R_2 SCORE\n")
max_score = max(score)  # Initialize max_score with the maximum value in the score list
max_model = ""

for model, score_value in zip(models, score):
    print(model, score_value)
    if score_value == max_score:
        max_model = model

print(f"\nModel: {max_model} contain Maximum R2_Score: {max_score} ")
# Out:
# FINDING BEST FIT MODEL FOR EVALUATION BASED ON R_2 SCORE
#
# ExtraTreeRegressor 0.8976936987926045
# DecisionTreeRegressor 0.8224282284723969
# XGBRegressor 0.8127493861931961
# SGDRegressor 0.27185225857565387
#
# Model: ExtraTreeRegressor contain Maximum R2_Score: 0.8976936987926045

# %%
model=et_model.fit(X_train, y_train)

# %%
model
# Out:
# ExtraTreesRegressor()

# %%
import pickle

file_path7='ExtraTreeRegressor.pkl'
with open(file_path7, 'wb') as file:
    pickle.dump(model, file)
print(f'Pickle file created: {file_path7}')
# Out:
# Pickle file created: ExtraTreeRegressor.pkl

# %%
with open('ExtraTreeRegressor.pkl', 'rb') as file:
    encode_status = pickle.load(file)

encode_status
# Out:
# ExtraTreesRegressor()

# %%
quantity=input('Enter quantity :')
thickness=input('Enter thickness :')
width=input('Enter width :')

new_sample_co = input("Enter a country: ")
c = None
for i, j in zip(country, transformed_country):
    if new_sample_co == i:
        c = j
        break
else:
    print("Country not found.")
    exit()

new_sample_st = input("Enter a status: ")
s = None
for i, j in zip(status, transformed_status):
    if new_sample_st == i:
        s = j
        break
else:
    print("Status not found.")
    exit()

new_sample_it = input("Enter an item type: ")
it = None
for i, j in zip(item, transformed_item):
    if new_sample_it == i:
        it = j
        break
else:
    print("Item type not found.")
    exit()

try:
  x = [quantity,thickness,width,c, s, it, 41.0,611993, 28]
  x = np.array(x).reshape(1, -1)  # Reshape to 2D array
  new_sample_scaled = scaler.transform(x)
  new_pred = et_model.predict(new_sample_scaled)
  print('Predicted selling price:',new_pred )
except:
  print('enter correct values')
# Out:
# Country not found.
# Status not found.
# Item type not found.
# enter correct values

# %% [markdown]
# # CLASSIFICATION MODEL FOR PREDICT THE STATUS WON/LOST

# %%
X = model_data[[ 'quantity tons','thickness','width','selling_price','country','item type','application','product_ref','delivery_time_taken']].values
y = model_data[['status']].values

scaler_classify = StandardScaler().fit(X)
X = scaler_classify.transform(X)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.27, random_state=27)

# %%
import pickle

file_path8='scaling_classify.pkl'
with open(file_path8, 'wb') as file:
    pickle.dump(scaler_classify, file)
print(f'Pickle file created: {file_path8}')
# Out:
# Pickle file created: scaling_classify.pkl

# %%
# Create an instance of each regression model
rf_model = RandomForestClassifier()                # Random Forest Classifier
xgb_cls_model = xgb.XGBClassifier()                # Extreme Gradient Classifier
dtc_model=DecisionTreeClassifier()                 # Decision Tree Classifier
sgdc_model = SGDClassifier()

# Train the models
rf_model.fit(X_train, y_train)
xgb_cls_model.fit(X_train, y_train)
dtc_model.fit(X_train,y_train)
sgdc_model.fit(X_train,y_train)

# Make predictions on the test set
rf_preds = rf_model.predict(X_test)
xgb_cls_preds = xgb_cls_model.predict(X_test)
dtc_preds = dtc_model.predict(X_test)
sgdc_preds = sgdc_model.predict(X_test)
# Evaluate the models
rf_accuracy = accuracy_score(y_test, rf_preds)
xgb_cls_accuracy = accuracy_score(y_test, xgb_cls_preds)
dtc_accuracy = accuracy_score(y_test, dtc_preds)
sgdc_accuracy = accuracy_score(y_test, sgdc_preds)

# %%
print(f"Random Forest Classifier Accuracy : {rf_accuracy}")
print(f"XGB Classifier Accuracy           : {xgb_cls_accuracy}")
print(f"Decision Tree Classifier Accuracy : {dtc_accuracy}")
print(f"SGD Classifier Accuracy          : {sgdc_accuracy}")
# Out:
# Random Forest Classifier Accuracy : 0.9184538856723478
# XGB Classifier Accuracy           : 0.8343594552719563
# Decision Tree Classifier Accuracy : 0.8855092554839762
# SGD Classifier Accuracy          : 0.6564869933947647

# %%
models = ['RandomForestClassifier', 'XGBClassifier','DecisionTreeClassifier','SGD Classifier']
score = [rf_accuracy, xgb_cls_accuracy,dtc_accuracy,sgdc_accuracy]

fig=px.bar(x=models, y=score,title='Accuracy of Classification Models')
fig.show()

print("FINDING BEST FIT MODEL FOR EVALUATION BASED ON  ACCURACY\n")
max_score = max(score)  # Initialize max_score with the maximum value in the score list
max_model = ""

for model, score_value in zip(models, score):
    print(model, score_value)
    if score_value == max_score:
        max_model = model

print(f"\nModel: {max_model} contain Maximum accuracy: {max_score} ")
# Out:
# FINDING BEST FIT MODEL FOR EVALUATION BASED ON  ACCURACY
#
# RandomForestClassifier 0.9184538856723478
# XGBClassifier 0.8343594552719563
# DecisionTreeClassifier 0.8855092554839762
# SGD Classifier 0.6564869933947647
#
# Model: RandomForestClassifier contain Maximum accuracy: 0.9184538856723478

# %%
model_cls=rf_model.fit(X_train, y_train)

# %%
model_cls
# Out:
# RandomForestClassifier()

# %%
file_path9='RandomForestClassification.pkl'
with open(file_path9, 'wb') as file:
    pickle.dump(model_cls, file)
print(f'Pickle file created: {file_path9}')
# Out:
# Pickle file created: RandomForestClassification.pkl

# %%
with open('RandomForestClassification.pkl', 'rb') as file:
    encode_status = pickle.load(file)

encode_status
# Out:
# RandomForestClassifier()

# %%
quantity=input('Enter quantity :')
thickness=input('Enter thickness :')
width=input('Enter width :')
selling_price=input('Enter selling price :')

new_sample_co = input("Enter a country: ")
c = None
for i, j in zip(country, transformed_country):
    if new_sample_co == i:
        c = j
        break
else:
    print("Country not found.")
    exit()

new_sample_it = input("Enter an item type: ")
it = None
for i, j in zip(item, transformed_item):
    if new_sample_it == i:
        it = j
        break
else:
    print("Item type not found.")
    exit()
try:
  x = [quantity,thickness,width,selling_price,c,it, 10.0,1670798778, 91]
  x = np.array(x).reshape(1, -1)  # Reshape to 2D array
  new_sample_scaled = scaler_classify.transform(x)
  new_pred = rf_model.predict(new_sample_scaled)

  if new_pred==6:
      print('WON' )
  else:
      print('LOST')
except:
  print("enter valid values")
# Out:
# LOST
